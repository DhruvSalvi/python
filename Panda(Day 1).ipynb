# %%
import pandas as pd
df = pd.read_csv('D:\\Data science\\weather1.csv')
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  03-01-2016           1             3       2016
# 1                    0.00  03-01-2016           1             3       2016
# 2                    0.16  03-01-2016           1             3       2016
# 3                    0.00  03-01-2016           1             3       2016
# 4                    0.01  03-01-2016           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  01-01-2017           1             1       2017
# 16739                0.00  01-01-2017           1             1       2017
# 16740                0.00  01-01-2017           1             1       2017
# 16741                0.06  01-01-2017           1             1       2017
# 16742                0.10  01-01-2017           1             1       2017
#
# ...

# %%
df['Max Temp'].max()
# Out:
# 111

# %%
df['Min Temp'].min()
# Out:
# -35

# %%
df['Wind Speed'].mean()
# Out:
# 6.3298202233769825

# %%
df['Wind Speed'].std()
# Out:
# 3.4947852525194727

# %%
df.shape
# Out:
# (16743, 14)

# %%
df.head()
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                0.00  03-01-2016           1             3       2016
# 1                0.00  03-01-2016           1             3       2016
# 2                0.16  03-01-2016           1             3       2016
# 3                0.00  03-01-2016           1             3       2016
# 4                0.01  03-01-2016           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  Avg Temp  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama        39
# 1   Huntsville          HSV   Huntsville, AL       Alabama        39
# 2       Mobile          MOB       Mobile, AL       Alabama        46
# 3   Montgomery          MGM   Montgomery, AL       Alabama        45
# 4    Anchorage          ANC    Anchorage, AK        Alaska        34
#
#    Max Temp  Min Temp  Wind Direction  Wind Speed
# 0        46        32              33        4.33
# ...

# %%
df.tail()
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 16738                0.08  01-01-2017           1             1       2017
# 16739                0.00  01-01-2017           1             1       2017
# 16740                0.00  01-01-2017           1             1       2017
# 16741                0.06  01-01-2017           1             1       2017
# 16742                0.10  01-01-2017           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  Avg Temp  \
# 16738       Casper          CPR       Casper, WY       Wyoming        23
# 16739     Cheyenne          CYS     Cheyenne, WY       Wyoming        32
# 16740       Lander          LND       Lander, WY       Wyoming        17
# 16741      Rawlins          RWL      Rawlins, WY       Wyoming        23
# 16742     Sheridan          SHR     Sheridan, WY       Wyoming        21
#
#        Max Temp  Min Temp  Wind Direction  Wind Speed
# ...

# %%
df[2:5]
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 2                0.16  03-01-2016           1             3       2016
# 3                0.00  03-01-2016           1             3       2016
# 4                0.01  03-01-2016           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  Avg Temp  \
# 2       Mobile          MOB       Mobile, AL       Alabama        46
# 3   Montgomery          MGM   Montgomery, AL       Alabama        45
# 4    Anchorage          ANC    Anchorage, AK        Alaska        34
#
#    Max Temp  Min Temp  Wind Direction  Wind Speed
# 2        51        41              35        9.73
# 3        52        38              32        6.86
# 4        38        29              19        7.80

# %%
df.columns
# Out:
# Index(['Data.Precipitation', 'Date.Full', 'Date.Month', 'Date.Week of',
#        'Date.Year', 'Station.City', 'Station.Code', 'Station.Location',
#        'Station.State', 'Avg Temp', 'Max Temp', 'Min Temp', 'Wind Direction',
#        'Wind Speed'],
#       dtype='object')

# %%
df['Avg Temp']
# Out:
# 0        39
# 1        39
# 2        46
# 3        45
# 4        34
#          ..
# 16738    23
# 16739    32
# 16740    17
# 16741    23
# 16742    21
# Name: Avg Temp, Length: 16743, dtype: int64

# %%
df['Avg Temp'].head()
# Out:
# 0    39
# 1    39
# 2    46
# 3    45
# 4    34
# Name: Avg Temp, dtype: int64

# %%
df['Max Temp'].max()
# Out:
# 111

# %%
df.describe()
# Out:
#        Data.Precipitation    Date.Month  Date.Week of     Date.Year  \
# count        16743.000000  16743.000000  16743.000000  16743.000000
# mean             0.579090      6.343128     15.650242   2016.018933
# std              0.988057      3.490723      8.923425      0.136294
# min              0.000000      1.000000      1.000000   2016.000000
# 25%              0.000000      3.000000      8.000000   2016.000000
# 50%              0.190000      6.000000     16.000000   2016.000000
# 75%              0.750000      9.000000     24.000000   2016.000000
# max             20.890000     12.000000     31.000000   2017.000000
#
#            Avg Temp      Max Temp      Min Temp  Wind Direction    Wind Speed
# count  16743.000000  16743.000000  16743.000000    16743.000000  16743.000000
# mean      56.089112     66.042406     45.642716       18.791316      6.329820
# std       18.798295     19.787954     18.559263        6.461527      3.494785
# ...
